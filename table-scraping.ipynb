# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

df = pd.read_html("https://en.wikipedia.org/wiki/List_of_Royal_Challengers_Bangalore_records")
df[0]
# Out:
#                                       0  \
# 0                                League
# 1                             Personnel
# 2                               Captain
# 3                                 Coach
# 4                                 Owner
# 5                      Team information
# 6                                  City
# 7                                Colors
# 8                               Founded
# 9                           Home ground
# 10                              History
# 11           Indian Premier League wins
# 12                           CLT20 wins
# 13                     Official website
# 14  Royal Challengers Bangalore in 2021
#
#                                            1
# 0                      Indian Premier League
# 1                                  Personnel
# 2                                Virat Kohli
# 3                               Simon Katich
# 4                             United Spirits
# ...

# %%
df = pd.DataFrame(df[0])
df.head()
# Out:
#            0                      1
# 0     League  Indian Premier League
# 1  Personnel              Personnel
# 2    Captain            Virat Kohli
# 3      Coach           Simon Katich
# 4      Owner         United Spirits

# %%
df.to_excel("Rcb details.xlsx", index=False,header=False)
print("Spreadsheet saved")
# Out:
# Spreadsheet saved

# %%
data = pd.read_html("https://en.wikipedia.org/wiki/List_of_Royal_Challengers_Bangalore_records")
data[1]
# Out:
#                                 Year                             Total  \
# 0                               2008                                14
# 1                               2009                                16
# 2                               2010                                16
# 3                               2011                                16
# 4                               2012                                16
# 5                               2013                                16
# 6                               2014                                14
# 7                               2015                                16
# 8                               2016                                16
# 9                               2017                                14
# 10                              2018                                14
# 11                              2019                                14
# ...

# %%
data.to_excel("Rcb_history.xlsx",index=False,header=False)
print("Spreadsheet saved")
# Out:
# Spreadsheet saved
